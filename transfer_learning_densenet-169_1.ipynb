# %%
import os

os.environ['KERAS_BACKEND'] = 'tensorflow'
os.environ['CUDA_HOME'] = '/usr/local/cuda-7.5'

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.layers import Dense, Dropout, Activation, Flatten, Lambda, BatchNormalization
from keras.layers import Convolution2D, MaxPooling2D, AveragePooling2D
from keras.layers import merge,Input 
from keras.engine import Model
from keras.optimizers import SGD
from keras.callbacks import Callback, LearningRateScheduler, ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
import keras.backend as K
import json
import time
nb_classes=85
# Out:
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Reading the train and test meta-data files
import pandas as pd
train = pd.read_csv('DL3 Dataset/train.csv')
test = pd.read_csv('DL3 Dataset/test.csv')

train.head()

# Shape of training and test datasets
print ('Training dataset consists of {} images with {} attributes'.format(train.shape[0], train.shape[1]-1))
# Shape of training and test datasets
print ('Testing dataset consists of {} images.'.format(test.shape[0]))
# Out:
# Training dataset consists of 12600 images with 85 attributes
# Testing dataset consists of 5400 images.

# %%
TRAIN_PATH = 'DL3 Dataset/train/'
TEST_PATH = 'DL3 Dataset/test/'
img_path = TRAIN_PATH+str(train.Image_name[0])
from PIL import Image
import cv2


# Extracting label columns
label_cols = list(set(train.columns) - set(['Image_name']))
label_cols.sort()


# Extracting labels corresponding to image at the zeroth index of the training dataset.
labels = train.iloc[0][2:].index[train.iloc[0][2:] == 1]

# %%
from tqdm import tqdm
def read_img(img_path):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (128,128))
    return img

# %%
train_img = []
for img_path in tqdm(train.Image_name.values):
    train_img.append(read_img(TRAIN_PATH + img_path))
# Out:
# 100%|██████████| 12600/12600 [06:23<00:00, 32.88it/s]

# %%
#reorder dimensions for tensorflow
X_train = np.array(train_img, np.float32) / 255.
print('x_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
del train_img
# Out:
# ('x_train shape:', (12600, 128, 128, 3))
# (12600, 'train samples')

# %% [markdown]
# import gc
# del train_img
# gc.collect()
#
# mean_img = X_train.mean(axis=0)
# std_dev = X_train.std(axis = 0)
# x_train = (X_train - mean_img)/ std_dev
#
# del X_train
# gc.collect()

# %%
y_train = train[label_cols].values
import gc
gc.collect()
# Out:
# 7

# %%
Xtrain, Xvalid, ytrain, yvalid = train_test_split(X_train, y_train, test_size=0.2, random_state=47)

del X_train
gc.collect()
#del train_img
# Out:
# 0

# %% [markdown]
# # test set

# %%
test_img = []
for img_path in tqdm(test.Image_name.values):
    test_img.append(read_img(TEST_PATH + img_path))
# Out:
# 100%|██████████| 5400/5400 [02:30<00:00, 35.97it/s]

# %%
X_test = np.array(test_img, np.float32) / 255.
del test_img
gc.collect()
# Out:
# 0

# %% [markdown]
# mean_img = X_test.mean(axis=0)
# std_dev = X_test.std(axis = 0)
# Xtest = (X_test - mean_img)/ std_dev
#
# del X_test
# gc.collect()

# %% [markdown]
# # densenet

# %%
from keras.optimizers import SGD
from keras.layers import Input, merge, ZeroPadding2D
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model


from custom_layers.scale_layer import Scale

# %%
def densenet169_model(img_rows, img_cols, color_type=1, nb_dense_block=4, growth_rate=32, nb_filter=64, reduction=0.5, dropout_rate=0.0, weight_decay=1e-4, num_classes=None):
    '''
    DenseNet 169 Model for Keras

    Model Schema is based on 
    https://github.com/flyyufelix/DenseNet-Keras

    ImageNet Pretrained Weights 
    Theano: https://drive.google.com/open?id=0Byy2AcGyEVxfN0d3T1F1MXg0NlU
    TensorFlow: https://drive.google.com/open?id=0Byy2AcGyEVxfSEc5UC1ROUFJdmM

        A Keras model instance.
    '''
    eps = 1.1e-5

    # compute compression factor
    compression = 1.0 - reduction

    # Handle Dimension Ordering for different backends
    global concat_axis
    if K.image_dim_ordering() == 'tf':
      concat_axis = 3
      img_input = Input(shape=(128,128, 3), name='data')
    else:
      concat_axis = 1
      img_input = Input(shape=(3, 128,128), name='data')

    # From architecture for ImageNet (Table 1 in the paper)
    nb_filter = 64
    nb_layers = [6,12,32,32] # For DenseNet-169

    # Initial convolution
    x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(img_input)
    x = Convolution2D(nb_filter, 7, 7, subsample=(2, 2), name='conv1', bias=False)(x)
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name='conv1_bn')(x)
    x = Scale(axis=concat_axis, name='conv1_scale')(x)
    x = Activation('relu', name='relu1')(x)
    x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)

    # Add dense blocks
    for block_idx in range(nb_dense_block - 1):
        stage = block_idx+2
        x, nb_filter = dense_block(x, stage, nb_layers[block_idx], nb_filter, growth_rate, dropout_rate=dropout_rate, weight_decay=weight_decay)

        # Add transition_block
        x = transition_block(x, stage, nb_filter, compression=compression, dropout_rate=dropout_rate, weight_decay=weight_decay)
        nb_filter = int(nb_filter * compression)

    final_stage = stage + 1
    x, nb_filter = dense_block(x, final_stage, nb_layers[-1], nb_filter, growth_rate, dropout_rate=dropout_rate, weight_decay=weight_decay)

    x = BatchNormalization(epsilon=eps, axis=concat_axis, name='conv'+str(final_stage)+'_blk_bn')(x)
    x = Scale(axis=concat_axis, name='conv'+str(final_stage)+'_blk_scale')(x)
    x = Activation('relu', name='relu'+str(final_stage)+'_blk')(x)

    x_fc = GlobalAveragePooling2D(name='pool'+str(final_stage))(x)
    x_fc = Dense(1000, name='fc6')(x_fc)
    x_fc = Activation('softmax', name='prob')(x_fc)

    model = Model(img_input, x_fc, name='densenet')

    if K.image_dim_ordering() == 'th':
      # Use pre-trained weights for Theano backend
      weights_path = 'densenet169_weights_th.h5'
    else:
      # Use pre-trained weights for Tensorflow backend
      weights_path = 'densenet169_weights_tf.h5'

    model.load_weights(weights_path, by_name=True)

    # Truncate and replace softmax layer for transfer learning
    # Cannot use model.layers.pop() since model is not of Sequential() type
    # The method below works since pre-trained weights are stored in layers but not in the model
    x_newfc = GlobalAveragePooling2D(name='pool'+str(final_stage))(x)
    x_newfc = Dense(num_classes, name='fc6')(x_newfc)
    x_newfc = Activation('sigmoid', name='prob')(x_newfc)

    model = Model(img_input, x_newfc)

    # Learning rate is changed to 0.001
    sgd = SGD(lr=1e-3, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='binary_crossentropy', metrics=['accuracy'])

    return model


def conv_block(x, stage, branch, nb_filter, dropout_rate=None, weight_decay=1e-4):
    '''Apply BatchNorm, Relu, bottleneck 1x1 Conv2D, 3x3 Conv2D, and option dropout
        # Arguments
            x: input tensor 
            stage: index for dense block
            branch: layer index within each dense block
            nb_filter: number of filters
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    '''
    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_' + str(branch)
    relu_name_base = 'relu' + str(stage) + '_' + str(branch)

    # 1x1 Convolution (Bottleneck layer)
    inter_channel = nb_filter * 4  
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_x1_bn')(x)
    x = Scale(axis=concat_axis, name=conv_name_base+'_x1_scale')(x)
    x = Activation('relu', name=relu_name_base+'_x1')(x)
    x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    # 3x3 Convolution
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_x2_bn')(x)
    x = Scale(axis=concat_axis, name=conv_name_base+'_x2_scale')(x)
    x = Activation('relu', name=relu_name_base+'_x2')(x)
    x = ZeroPadding2D((1, 1), name=conv_name_base+'_x2_zeropadding')(x)
    x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x


def transition_block(x, stage, nb_filter, compression=1.0, dropout_rate=None, weight_decay=1E-4):
    ''' Apply BatchNorm, 1x1 Convolution, averagePooling, optional compression, dropout 
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_filter: number of filters
            compression: calculated as 1 - reduction. Reduces the number of feature maps in the transition block.
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    '''

    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_blk'
    relu_name_base = 'relu' + str(stage) + '_blk'
    pool_name_base = 'pool' + str(stage) 

    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_bn')(x)
    x = Scale(axis=concat_axis, name=conv_name_base+'_scale')(x)
    x = Activation('relu', name=relu_name_base)(x)
    x = Convolution2D(int(nb_filter * compression), 1, 1, name=conv_name_base, bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    x = AveragePooling2D((2, 2), strides=(2, 2), name=pool_name_base)(x)

    return x


def dense_block(x, stage, nb_layers, nb_filter, growth_rate, dropout_rate=None, weight_decay=1e-4, grow_nb_filters=True):
    ''' Build a dense_block where the output of each conv_block is fed to subsequent ones
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_layers: the number of layers of conv_block to append to the model.
            nb_filter: number of filters
            growth_rate: growth rate
            dropout_rate: dropout rate
            weight_decay: weight decay factor
            grow_nb_filters: flag to decide to allow number of filters to grow
    '''

    eps = 1.1e-5
    concat_feat = x

    for i in range(nb_layers):
        branch = i+1
        x = conv_block(concat_feat, stage, branch, growth_rate, dropout_rate, weight_decay)
        concat_feat = merge([concat_feat, x], mode='concat', concat_axis=concat_axis, name='concat_'+str(stage)+'_'+str(branch))

        if grow_nb_filters:
            nb_filter += growth_rate

    return concat_feat, nb_filter

# %%
img_rows, img_cols = 128,128 # Resolution of inputs
channel = 3
num_classes = 85
batch_size = 16 
nb_epoch = 10



# Load our model
model = densenet169_model(img_rows=img_rows, img_cols=img_cols, color_type=channel, num_classes=num_classes)
# Out:
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (7, 7), strides=(2, 2), use_bias=False, name="conv1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_1_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_1_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:173: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/keras/legacy/layers.py:465: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_2_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_2_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_3_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_3_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_4_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_4_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_5_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_5_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_6_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_6_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:144: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_blk")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_1_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_1_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_2_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_2_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_3_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_3_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_4_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_4_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_5_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_5_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_6_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_6_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_7_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_7_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_8_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_8_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_9_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_9_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_10_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_10_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_11_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_11_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_12_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_12_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:144: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="conv3_blk")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_1_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_1_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_2_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_2_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_3_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_3_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_4_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_4_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_5_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_5_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_6_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_6_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_7_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_7_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_8_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_8_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_9_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_9_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_10_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_10_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_11_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_11_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_12_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_12_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_13_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_13_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_14_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_14_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_15_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_15_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_16_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_16_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_17_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_17_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_18_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_18_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_19_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_19_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_20_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_20_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_21_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_21_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_22_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_22_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_23_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_23_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_24_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_24_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_25_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_25_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_26_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_26_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_27_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_27_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_28_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_28_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_29_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_29_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_30_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_30_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_31_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_31_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_32_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_32_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:144: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(640, (1, 1), use_bias=False, name="conv4_blk")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_1_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_1_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_2_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_2_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_3_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_3_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_4_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_4_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_5_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_5_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_6_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_6_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_7_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_7_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_8_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_8_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_9_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_9_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_10_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_10_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_11_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_11_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_12_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_12_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_13_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_13_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_14_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_14_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_15_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_15_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_16_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_16_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_17_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_17_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_18_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_18_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_19_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_19_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_20_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_20_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_21_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_21_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_22_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_22_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_23_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_23_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_24_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_24_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_25_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_25_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_26_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_26_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_27_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_27_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_28_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_28_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_29_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_29_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_30_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_30_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_31_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_31_x2")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_32_x1")`
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:117: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_32_x2")`

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# conv1_zeropadding (ZeroPadding2 (None, 134, 134, 3)  0           data[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 64, 64)   9408        conv1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 64, 64, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_scale (Scale)             (None, 64, 64, 64)   128         conv1_bn[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 64, 64, 64)   0           conv1_scale[0][0]
# __________________________________________________________________________________________________
# pool1_zeropadding (ZeroPadding2 (None, 66, 66, 64)   0           relu1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 32, 32, 64)   0           pool1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1_bn (BatchNormalizati (None, 32, 32, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1_scale (Scale)        (None, 32, 32, 64)   128         conv2_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_1_x1 (Activation)         (None, 32, 32, 64)   0           conv2_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1 (Conv2D)             (None, 32, 32, 128)  8192        relu2_1_x1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_bn (BatchNormalizati (None, 32, 32, 128)  512         conv2_1_x1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_scale (Scale)        (None, 32, 32, 128)  256         conv2_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_1_x2 (Activation)         (None, 32, 32, 128)  0           conv2_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_zeropadding (ZeroPad (None, 34, 34, 128)  0           relu2_1_x2[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2 (Conv2D)             (None, 32, 32, 32)   36864       conv2_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_1 (Merge)              (None, 32, 32, 96)   0           pool1[0][0]
#                                                                  conv2_1_x2[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1_bn (BatchNormalizati (None, 32, 32, 96)   384         concat_2_1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1_scale (Scale)        (None, 32, 32, 96)   192         conv2_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_2_x1 (Activation)         (None, 32, 32, 96)   0           conv2_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1 (Conv2D)             (None, 32, 32, 128)  12288       relu2_2_x1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_bn (BatchNormalizati (None, 32, 32, 128)  512         conv2_2_x1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_scale (Scale)        (None, 32, 32, 128)  256         conv2_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_2_x2 (Activation)         (None, 32, 32, 128)  0           conv2_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_zeropadding (ZeroPad (None, 34, 34, 128)  0           relu2_2_x2[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2 (Conv2D)             (None, 32, 32, 32)   36864       conv2_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_2 (Merge)              (None, 32, 32, 128)  0           concat_2_1[0][0]
#                                                                  conv2_2_x2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1_bn (BatchNormalizati (None, 32, 32, 128)  512         concat_2_2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1_scale (Scale)        (None, 32, 32, 128)  256         conv2_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_3_x1 (Activation)         (None, 32, 32, 128)  0           conv2_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1 (Conv2D)             (None, 32, 32, 128)  16384       relu2_3_x1[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_bn (BatchNormalizati (None, 32, 32, 128)  512         conv2_3_x1[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_scale (Scale)        (None, 32, 32, 128)  256         conv2_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_3_x2 (Activation)         (None, 32, 32, 128)  0           conv2_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_zeropadding (ZeroPad (None, 34, 34, 128)  0           relu2_3_x2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2 (Conv2D)             (None, 32, 32, 32)   36864       conv2_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_3 (Merge)              (None, 32, 32, 160)  0           concat_2_2[0][0]
#                                                                  conv2_3_x2[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1_bn (BatchNormalizati (None, 32, 32, 160)  640         concat_2_3[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1_scale (Scale)        (None, 32, 32, 160)  320         conv2_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_4_x1 (Activation)         (None, 32, 32, 160)  0           conv2_4_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1 (Conv2D)             (None, 32, 32, 128)  20480       relu2_4_x1[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_bn (BatchNormalizati (None, 32, 32, 128)  512         conv2_4_x1[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_scale (Scale)        (None, 32, 32, 128)  256         conv2_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_4_x2 (Activation)         (None, 32, 32, 128)  0           conv2_4_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_zeropadding (ZeroPad (None, 34, 34, 128)  0           relu2_4_x2[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2 (Conv2D)             (None, 32, 32, 32)   36864       conv2_4_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_4 (Merge)              (None, 32, 32, 192)  0           concat_2_3[0][0]
#                                                                  conv2_4_x2[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1_bn (BatchNormalizati (None, 32, 32, 192)  768         concat_2_4[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1_scale (Scale)        (None, 32, 32, 192)  384         conv2_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_5_x1 (Activation)         (None, 32, 32, 192)  0           conv2_5_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1 (Conv2D)             (None, 32, 32, 128)  24576       relu2_5_x1[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_bn (BatchNormalizati (None, 32, 32, 128)  512         conv2_5_x1[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_scale (Scale)        (None, 32, 32, 128)  256         conv2_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_5_x2 (Activation)         (None, 32, 32, 128)  0           conv2_5_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_zeropadding (ZeroPad (None, 34, 34, 128)  0           relu2_5_x2[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2 (Conv2D)             (None, 32, 32, 32)   36864       conv2_5_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_5 (Merge)              (None, 32, 32, 224)  0           concat_2_4[0][0]
#                                                                  conv2_5_x2[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1_bn (BatchNormalizati (None, 32, 32, 224)  896         concat_2_5[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1_scale (Scale)        (None, 32, 32, 224)  448         conv2_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_6_x1 (Activation)         (None, 32, 32, 224)  0           conv2_6_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1 (Conv2D)             (None, 32, 32, 128)  28672       relu2_6_x1[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_bn (BatchNormalizati (None, 32, 32, 128)  512         conv2_6_x1[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_scale (Scale)        (None, 32, 32, 128)  256         conv2_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_6_x2 (Activation)         (None, 32, 32, 128)  0           conv2_6_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_zeropadding (ZeroPad (None, 34, 34, 128)  0           relu2_6_x2[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2 (Conv2D)             (None, 32, 32, 32)   36864       conv2_6_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_6 (Merge)              (None, 32, 32, 256)  0           concat_2_5[0][0]
#                                                                  conv2_6_x2[0][0]
# __________________________________________________________________________________________________
# conv2_blk_bn (BatchNormalizatio (None, 32, 32, 256)  1024        concat_2_6[0][0]
# __________________________________________________________________________________________________
# conv2_blk_scale (Scale)         (None, 32, 32, 256)  512         conv2_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu2_blk (Activation)          (None, 32, 32, 256)  0           conv2_blk_scale[0][0]
# __________________________________________________________________________________________________
# conv2_blk (Conv2D)              (None, 32, 32, 128)  32768       relu2_blk[0][0]
# __________________________________________________________________________________________________
# pool2 (AveragePooling2D)        (None, 16, 16, 128)  0           conv2_blk[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1_bn (BatchNormalizati (None, 16, 16, 128)  512         pool2[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1_scale (Scale)        (None, 16, 16, 128)  256         conv3_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_1_x1 (Activation)         (None, 16, 16, 128)  0           conv3_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1 (Conv2D)             (None, 16, 16, 128)  16384       relu3_1_x1[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_bn (BatchNormalizati (None, 16, 16, 128)  512         conv3_1_x1[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_scale (Scale)        (None, 16, 16, 128)  256         conv3_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_1_x2 (Activation)         (None, 16, 16, 128)  0           conv3_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_zeropadding (ZeroPad (None, 18, 18, 128)  0           relu3_1_x2[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2 (Conv2D)             (None, 16, 16, 32)   36864       conv3_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_1 (Merge)              (None, 16, 16, 160)  0           pool2[0][0]
#                                                                  conv3_1_x2[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1_bn (BatchNormalizati (None, 16, 16, 160)  640         concat_3_1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1_scale (Scale)        (None, 16, 16, 160)  320         conv3_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_2_x1 (Activation)         (None, 16, 16, 160)  0           conv3_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1 (Conv2D)             (None, 16, 16, 128)  20480       relu3_2_x1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_bn (BatchNormalizati (None, 16, 16, 128)  512         conv3_2_x1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_scale (Scale)        (None, 16, 16, 128)  256         conv3_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_2_x2 (Activation)         (None, 16, 16, 128)  0           conv3_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_zeropadding (ZeroPad (None, 18, 18, 128)  0           relu3_2_x2[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2 (Conv2D)             (None, 16, 16, 32)   36864       conv3_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_2 (Merge)              (None, 16, 16, 192)  0           concat_3_1[0][0]
#                                                                  conv3_2_x2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1_bn (BatchNormalizati (None, 16, 16, 192)  768         concat_3_2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1_scale (Scale)        (None, 16, 16, 192)  384         conv3_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_3_x1 (Activation)         (None, 16, 16, 192)  0           conv3_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1 (Conv2D)             (None, 16, 16, 128)  24576       relu3_3_x1[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_bn (BatchNormalizati (None, 16, 16, 128)  512         conv3_3_x1[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_scale (Scale)        (None, 16, 16, 128)  256         conv3_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_3_x2 (Activation)         (None, 16, 16, 128)  0           conv3_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_zeropadding (ZeroPad (None, 18, 18, 128)  0           relu3_3_x2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2 (Conv2D)             (None, 16, 16, 32)   36864       conv3_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_3 (Merge)              (None, 16, 16, 224)  0           concat_3_2[0][0]
#                                                                  conv3_3_x2[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1_bn (BatchNormalizati (None, 16, 16, 224)  896         concat_3_3[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1_scale (Scale)        (None, 16, 16, 224)  448         conv3_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_4_x1 (Activation)         (None, 16, 16, 224)  0           conv3_4_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1 (Conv2D)             (None, 16, 16, 128)  28672       relu3_4_x1[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_bn (BatchNormalizati (None, 16, 16, 128)  512         conv3_4_x1[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_scale (Scale)        (None, 16, 16, 128)  256         conv3_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_4_x2 (Activation)         (None, 16, 16, 128)  0           conv3_4_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_zeropadding (ZeroPad (None, 18, 18, 128)  0           relu3_4_x2[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2 (Conv2D)             (None, 16, 16, 32)   36864       conv3_4_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_4 (Merge)              (None, 16, 16, 256)  0           concat_3_3[0][0]
#                                                                  conv3_4_x2[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1_bn (BatchNormalizati (None, 16, 16, 256)  1024        concat_3_4[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1_scale (Scale)        (None, 16, 16, 256)  512         conv3_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_5_x1 (Activation)         (None, 16, 16, 256)  0           conv3_5_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1 (Conv2D)             (None, 16, 16, 128)  32768       relu3_5_x1[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_bn (BatchNormalizati (None, 16, 16, 128)  512         conv3_5_x1[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_scale (Scale)        (None, 16, 16, 128)  256         conv3_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_5_x2 (Activation)         (None, 16, 16, 128)  0           conv3_5_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_zeropadding (ZeroPad (None, 18, 18, 128)  0           relu3_5_x2[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2 (Conv2D)             (None, 16, 16, 32)   36864       conv3_5_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_5 (Merge)              (None, 16, 16, 288)  0           concat_3_4[0][0]
#                                                                  conv3_5_x2[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1_bn (BatchNormalizati (None, 16, 16, 288)  1152        concat_3_5[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1_scale (Scale)        (None, 16, 16, 288)  576         conv3_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_6_x1 (Activation)         (None, 16, 16, 288)  0           conv3_6_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1 (Conv2D)             (None, 16, 16, 128)  36864       relu3_6_x1[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_bn (BatchNormalizati (None, 16, 16, 128)  512         conv3_6_x1[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_scale (Scale)        (None, 16, 16, 128)  256         conv3_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_6_x2 (Activation)         (None, 16, 16, 128)  0           conv3_6_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_zeropadding (ZeroPad (None, 18, 18, 128)  0           relu3_6_x2[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2 (Conv2D)             (None, 16, 16, 32)   36864       conv3_6_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_6 (Merge)              (None, 16, 16, 320)  0           concat_3_5[0][0]
#                                                                  conv3_6_x2[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1_bn (BatchNormalizati (None, 16, 16, 320)  1280        concat_3_6[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1_scale (Scale)        (None, 16, 16, 320)  640         conv3_7_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_7_x1 (Activation)         (None, 16, 16, 320)  0           conv3_7_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1 (Conv2D)             (None, 16, 16, 128)  40960       relu3_7_x1[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_bn (BatchNormalizati (None, 16, 16, 128)  512         conv3_7_x1[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_scale (Scale)        (None, 16, 16, 128)  256         conv3_7_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_7_x2 (Activation)         (None, 16, 16, 128)  0           conv3_7_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_zeropadding (ZeroPad (None, 18, 18, 128)  0           relu3_7_x2[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2 (Conv2D)             (None, 16, 16, 32)   36864       conv3_7_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_7 (Merge)              (None, 16, 16, 352)  0           concat_3_6[0][0]
#                                                                  conv3_7_x2[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1_bn (BatchNormalizati (None, 16, 16, 352)  1408        concat_3_7[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1_scale (Scale)        (None, 16, 16, 352)  704         conv3_8_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_8_x1 (Activation)         (None, 16, 16, 352)  0           conv3_8_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1 (Conv2D)             (None, 16, 16, 128)  45056       relu3_8_x1[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_bn (BatchNormalizati (None, 16, 16, 128)  512         conv3_8_x1[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_scale (Scale)        (None, 16, 16, 128)  256         conv3_8_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_8_x2 (Activation)         (None, 16, 16, 128)  0           conv3_8_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_zeropadding (ZeroPad (None, 18, 18, 128)  0           relu3_8_x2[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2 (Conv2D)             (None, 16, 16, 32)   36864       conv3_8_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_8 (Merge)              (None, 16, 16, 384)  0           concat_3_7[0][0]
#                                                                  conv3_8_x2[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1_bn (BatchNormalizati (None, 16, 16, 384)  1536        concat_3_8[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1_scale (Scale)        (None, 16, 16, 384)  768         conv3_9_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_9_x1 (Activation)         (None, 16, 16, 384)  0           conv3_9_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1 (Conv2D)             (None, 16, 16, 128)  49152       relu3_9_x1[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_bn (BatchNormalizati (None, 16, 16, 128)  512         conv3_9_x1[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_scale (Scale)        (None, 16, 16, 128)  256         conv3_9_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_9_x2 (Activation)         (None, 16, 16, 128)  0           conv3_9_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_zeropadding (ZeroPad (None, 18, 18, 128)  0           relu3_9_x2[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2 (Conv2D)             (None, 16, 16, 32)   36864       conv3_9_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_9 (Merge)              (None, 16, 16, 416)  0           concat_3_8[0][0]
#                                                                  conv3_9_x2[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1_bn (BatchNormalizat (None, 16, 16, 416)  1664        concat_3_9[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1_scale (Scale)       (None, 16, 16, 416)  832         conv3_10_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_10_x1 (Activation)        (None, 16, 16, 416)  0           conv3_10_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1 (Conv2D)            (None, 16, 16, 128)  53248       relu3_10_x1[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_bn (BatchNormalizat (None, 16, 16, 128)  512         conv3_10_x1[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_scale (Scale)       (None, 16, 16, 128)  256         conv3_10_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_10_x2 (Activation)        (None, 16, 16, 128)  0           conv3_10_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_zeropadding (ZeroPa (None, 18, 18, 128)  0           relu3_10_x2[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2 (Conv2D)            (None, 16, 16, 32)   36864       conv3_10_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_10 (Merge)             (None, 16, 16, 448)  0           concat_3_9[0][0]
#                                                                  conv3_10_x2[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1_bn (BatchNormalizat (None, 16, 16, 448)  1792        concat_3_10[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1_scale (Scale)       (None, 16, 16, 448)  896         conv3_11_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_11_x1 (Activation)        (None, 16, 16, 448)  0           conv3_11_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1 (Conv2D)            (None, 16, 16, 128)  57344       relu3_11_x1[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_bn (BatchNormalizat (None, 16, 16, 128)  512         conv3_11_x1[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_scale (Scale)       (None, 16, 16, 128)  256         conv3_11_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_11_x2 (Activation)        (None, 16, 16, 128)  0           conv3_11_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_zeropadding (ZeroPa (None, 18, 18, 128)  0           relu3_11_x2[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2 (Conv2D)            (None, 16, 16, 32)   36864       conv3_11_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_11 (Merge)             (None, 16, 16, 480)  0           concat_3_10[0][0]
#                                                                  conv3_11_x2[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1_bn (BatchNormalizat (None, 16, 16, 480)  1920        concat_3_11[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1_scale (Scale)       (None, 16, 16, 480)  960         conv3_12_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_12_x1 (Activation)        (None, 16, 16, 480)  0           conv3_12_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1 (Conv2D)            (None, 16, 16, 128)  61440       relu3_12_x1[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_bn (BatchNormalizat (None, 16, 16, 128)  512         conv3_12_x1[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_scale (Scale)       (None, 16, 16, 128)  256         conv3_12_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_12_x2 (Activation)        (None, 16, 16, 128)  0           conv3_12_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_zeropadding (ZeroPa (None, 18, 18, 128)  0           relu3_12_x2[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2 (Conv2D)            (None, 16, 16, 32)   36864       conv3_12_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_12 (Merge)             (None, 16, 16, 512)  0           concat_3_11[0][0]
#                                                                  conv3_12_x2[0][0]
# __________________________________________________________________________________________________
# conv3_blk_bn (BatchNormalizatio (None, 16, 16, 512)  2048        concat_3_12[0][0]
# __________________________________________________________________________________________________
# conv3_blk_scale (Scale)         (None, 16, 16, 512)  1024        conv3_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu3_blk (Activation)          (None, 16, 16, 512)  0           conv3_blk_scale[0][0]
# __________________________________________________________________________________________________
# conv3_blk (Conv2D)              (None, 16, 16, 256)  131072      relu3_blk[0][0]
# __________________________________________________________________________________________________
# pool3 (AveragePooling2D)        (None, 8, 8, 256)    0           conv3_blk[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1_bn (BatchNormalizati (None, 8, 8, 256)    1024        pool3[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1_scale (Scale)        (None, 8, 8, 256)    512         conv4_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_1_x1 (Activation)         (None, 8, 8, 256)    0           conv4_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1 (Conv2D)             (None, 8, 8, 128)    32768       relu4_1_x1[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_bn (BatchNormalizati (None, 8, 8, 128)    512         conv4_1_x1[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_scale (Scale)        (None, 8, 8, 128)    256         conv4_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_1_x2 (Activation)         (None, 8, 8, 128)    0           conv4_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_zeropadding (ZeroPad (None, 10, 10, 128)  0           relu4_1_x2[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2 (Conv2D)             (None, 8, 8, 32)     36864       conv4_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_4_1 (Merge)              (None, 8, 8, 288)    0           pool3[0][0]
#                                                                  conv4_1_x2[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1_bn (BatchNormalizati (None, 8, 8, 288)    1152        concat_4_1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1_scale (Scale)        (None, 8, 8, 288)    576         conv4_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_2_x1 (Activation)         (None, 8, 8, 288)    0           conv4_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1 (Conv2D)             (None, 8, 8, 128)    36864       relu4_2_x1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_bn (BatchNormalizati (None, 8, 8, 128)    512         conv4_2_x1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_scale (Scale)        (None, 8, 8, 128)    256         conv4_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_2_x2 (Activation)         (None, 8, 8, 128)    0           conv4_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_zeropadding (ZeroPad (None, 10, 10, 128)  0           relu4_2_x2[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2 (Conv2D)             (None, 8, 8, 32)     36864       conv4_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_4_2 (Merge)              (None, 8, 8, 320)    0           concat_4_1[0][0]
#                                                                  conv4_2_x2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1_bn (BatchNormalizati (None, 8, 8, 320)    1280        concat_4_2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1_scale (Scale)        (None, 8, 8, 320)    640         conv4_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_3_x1 (Activation)         (None, 8, 8, 320)    0           conv4_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1 (Conv2D)             (None, 8, 8, 128)    40960       relu4_3_x1[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_bn (BatchNormalizati (None, 8, 8, 128)    512         conv4_3_x1[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_scale (Scale)        (None, 8, 8, 128)    256         conv4_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_3_x2 (Activation)         (None, 8, 8, 128)    0           conv4_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_zeropadding (ZeroPad (None, 10, 10, 128)  0           relu4_3_x2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2 (Conv2D)             (None, 8, 8, 32)     36864       conv4_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_4_3 (Merge)              (None, 8, 8, 352)    0           concat_4_2[0][0]
#                                                                  conv4_3_x2[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1_bn (BatchNormalizati (None, 8, 8, 352)    1408        concat_4_3[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1_scale (Scale)        (None, 8, 8, 352)    704         conv4_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# ...
# conv5_26_x1_bn (BatchNormalizat (None, 4, 4, 1440)   5760        concat_5_25[0][0]
# __________________________________________________________________________________________________
# conv5_26_x1_scale (Scale)       (None, 4, 4, 1440)   2880        conv5_26_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_26_x1 (Activation)        (None, 4, 4, 1440)   0           conv5_26_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_26_x1 (Conv2D)            (None, 4, 4, 128)    184320      relu5_26_x1[0][0]
# __________________________________________________________________________________________________
# conv5_26_x2_bn (BatchNormalizat (None, 4, 4, 128)    512         conv5_26_x1[0][0]
# __________________________________________________________________________________________________
# conv5_26_x2_scale (Scale)       (None, 4, 4, 128)    256         conv5_26_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_26_x2 (Activation)        (None, 4, 4, 128)    0           conv5_26_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_26_x2_zeropadding (ZeroPa (None, 6, 6, 128)    0           relu5_26_x2[0][0]
# __________________________________________________________________________________________________
# conv5_26_x2 (Conv2D)            (None, 4, 4, 32)     36864       conv5_26_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_26 (Merge)             (None, 4, 4, 1472)   0           concat_5_25[0][0]
#                                                                  conv5_26_x2[0][0]
# __________________________________________________________________________________________________
# conv5_27_x1_bn (BatchNormalizat (None, 4, 4, 1472)   5888        concat_5_26[0][0]
# __________________________________________________________________________________________________
# conv5_27_x1_scale (Scale)       (None, 4, 4, 1472)   2944        conv5_27_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_27_x1 (Activation)        (None, 4, 4, 1472)   0           conv5_27_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_27_x1 (Conv2D)            (None, 4, 4, 128)    188416      relu5_27_x1[0][0]
# __________________________________________________________________________________________________
# conv5_27_x2_bn (BatchNormalizat (None, 4, 4, 128)    512         conv5_27_x1[0][0]
# __________________________________________________________________________________________________
# conv5_27_x2_scale (Scale)       (None, 4, 4, 128)    256         conv5_27_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_27_x2 (Activation)        (None, 4, 4, 128)    0           conv5_27_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_27_x2_zeropadding (ZeroPa (None, 6, 6, 128)    0           relu5_27_x2[0][0]
# __________________________________________________________________________________________________
# conv5_27_x2 (Conv2D)            (None, 4, 4, 32)     36864       conv5_27_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_27 (Merge)             (None, 4, 4, 1504)   0           concat_5_26[0][0]
#                                                                  conv5_27_x2[0][0]
# __________________________________________________________________________________________________
# conv5_28_x1_bn (BatchNormalizat (None, 4, 4, 1504)   6016        concat_5_27[0][0]
# __________________________________________________________________________________________________
# conv5_28_x1_scale (Scale)       (None, 4, 4, 1504)   3008        conv5_28_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_28_x1 (Activation)        (None, 4, 4, 1504)   0           conv5_28_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_28_x1 (Conv2D)            (None, 4, 4, 128)    192512      relu5_28_x1[0][0]
# __________________________________________________________________________________________________
# conv5_28_x2_bn (BatchNormalizat (None, 4, 4, 128)    512         conv5_28_x1[0][0]
# __________________________________________________________________________________________________
# conv5_28_x2_scale (Scale)       (None, 4, 4, 128)    256         conv5_28_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_28_x2 (Activation)        (None, 4, 4, 128)    0           conv5_28_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_28_x2_zeropadding (ZeroPa (None, 6, 6, 128)    0           relu5_28_x2[0][0]
# __________________________________________________________________________________________________
# conv5_28_x2 (Conv2D)            (None, 4, 4, 32)     36864       conv5_28_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_28 (Merge)             (None, 4, 4, 1536)   0           concat_5_27[0][0]
#                                                                  conv5_28_x2[0][0]
# __________________________________________________________________________________________________
# conv5_29_x1_bn (BatchNormalizat (None, 4, 4, 1536)   6144        concat_5_28[0][0]
# __________________________________________________________________________________________________
# conv5_29_x1_scale (Scale)       (None, 4, 4, 1536)   3072        conv5_29_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_29_x1 (Activation)        (None, 4, 4, 1536)   0           conv5_29_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_29_x1 (Conv2D)            (None, 4, 4, 128)    196608      relu5_29_x1[0][0]
# __________________________________________________________________________________________________
# conv5_29_x2_bn (BatchNormalizat (None, 4, 4, 128)    512         conv5_29_x1[0][0]
# __________________________________________________________________________________________________
# conv5_29_x2_scale (Scale)       (None, 4, 4, 128)    256         conv5_29_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_29_x2 (Activation)        (None, 4, 4, 128)    0           conv5_29_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_29_x2_zeropadding (ZeroPa (None, 6, 6, 128)    0           relu5_29_x2[0][0]
# __________________________________________________________________________________________________
# conv5_29_x2 (Conv2D)            (None, 4, 4, 32)     36864       conv5_29_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_29 (Merge)             (None, 4, 4, 1568)   0           concat_5_28[0][0]
#                                                                  conv5_29_x2[0][0]
# __________________________________________________________________________________________________
# conv5_30_x1_bn (BatchNormalizat (None, 4, 4, 1568)   6272        concat_5_29[0][0]
# __________________________________________________________________________________________________
# conv5_30_x1_scale (Scale)       (None, 4, 4, 1568)   3136        conv5_30_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_30_x1 (Activation)        (None, 4, 4, 1568)   0           conv5_30_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_30_x1 (Conv2D)            (None, 4, 4, 128)    200704      relu5_30_x1[0][0]
# __________________________________________________________________________________________________
# conv5_30_x2_bn (BatchNormalizat (None, 4, 4, 128)    512         conv5_30_x1[0][0]
# __________________________________________________________________________________________________
# conv5_30_x2_scale (Scale)       (None, 4, 4, 128)    256         conv5_30_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_30_x2 (Activation)        (None, 4, 4, 128)    0           conv5_30_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_30_x2_zeropadding (ZeroPa (None, 6, 6, 128)    0           relu5_30_x2[0][0]
# __________________________________________________________________________________________________
# conv5_30_x2 (Conv2D)            (None, 4, 4, 32)     36864       conv5_30_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_30 (Merge)             (None, 4, 4, 1600)   0           concat_5_29[0][0]
#                                                                  conv5_30_x2[0][0]
# __________________________________________________________________________________________________
# conv5_31_x1_bn (BatchNormalizat (None, 4, 4, 1600)   6400        concat_5_30[0][0]
# __________________________________________________________________________________________________
# conv5_31_x1_scale (Scale)       (None, 4, 4, 1600)   3200        conv5_31_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_31_x1 (Activation)        (None, 4, 4, 1600)   0           conv5_31_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_31_x1 (Conv2D)            (None, 4, 4, 128)    204800      relu5_31_x1[0][0]
# __________________________________________________________________________________________________
# conv5_31_x2_bn (BatchNormalizat (None, 4, 4, 128)    512         conv5_31_x1[0][0]
# __________________________________________________________________________________________________
# conv5_31_x2_scale (Scale)       (None, 4, 4, 128)    256         conv5_31_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_31_x2 (Activation)        (None, 4, 4, 128)    0           conv5_31_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_31_x2_zeropadding (ZeroPa (None, 6, 6, 128)    0           relu5_31_x2[0][0]
# __________________________________________________________________________________________________
# conv5_31_x2 (Conv2D)            (None, 4, 4, 32)     36864       conv5_31_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_31 (Merge)             (None, 4, 4, 1632)   0           concat_5_30[0][0]
#                                                                  conv5_31_x2[0][0]
# __________________________________________________________________________________________________
# conv5_32_x1_bn (BatchNormalizat (None, 4, 4, 1632)   6528        concat_5_31[0][0]
# __________________________________________________________________________________________________
# conv5_32_x1_scale (Scale)       (None, 4, 4, 1632)   3264        conv5_32_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_32_x1 (Activation)        (None, 4, 4, 1632)   0           conv5_32_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_32_x1 (Conv2D)            (None, 4, 4, 128)    208896      relu5_32_x1[0][0]
# __________________________________________________________________________________________________
# conv5_32_x2_bn (BatchNormalizat (None, 4, 4, 128)    512         conv5_32_x1[0][0]
# __________________________________________________________________________________________________
# conv5_32_x2_scale (Scale)       (None, 4, 4, 128)    256         conv5_32_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_32_x2 (Activation)        (None, 4, 4, 128)    0           conv5_32_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_32_x2_zeropadding (ZeroPa (None, 6, 6, 128)    0           relu5_32_x2[0][0]
# __________________________________________________________________________________________________
# conv5_32_x2 (Conv2D)            (None, 4, 4, 32)     36864       conv5_32_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_32 (Merge)             (None, 4, 4, 1664)   0           concat_5_31[0][0]
#                                                                  conv5_32_x2[0][0]
# __________________________________________________________________________________________________
# conv5_blk_bn (BatchNormalizatio (None, 4, 4, 1664)   6656        concat_5_32[0][0]
# __________________________________________________________________________________________________
# conv5_blk_scale (Scale)         (None, 4, 4, 1664)   3328        conv5_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu5_blk (Activation)          (None, 4, 4, 1664)   0           conv5_blk_scale[0][0]
# __________________________________________________________________________________________________
# pool5 (GlobalAveragePooling2D)  (None, 1664)         0           relu5_blk[0][0]
# __________________________________________________________________________________________________
# fc6 (Dense)                     (None, 85)           141525      pool5[0][0]
# __________________________________________________________________________________________________
# prob (Activation)               (None, 85)           0           fc6[0][0]
# ==================================================================================================
# Total params: 12,942,805
# Trainable params: 12,784,405
# Non-trainable params: 158,400
# __________________________________________________________________________________________________

# %%
early_stops = EarlyStopping(patience=3, monitor='val_acc')
checkpointer = ModelCheckpoint(filepath='weights_densenet-169.hdf5', verbose=1, save_best_only=True)
# Start Fine-tuning

model.fit(Xtrain, ytrain,
          validation_data=(Xvalid, yvalid),
          batch_size=batch_size,
          nb_epoch=nb_epoch,
          shuffle=True,
          verbose=1,
          callbacks=[checkpointer])
# Out:
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:11: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   # This is added back by InteractiveShellApp.init_path()
# WARNING:tensorflow:Variable *= will be deprecated. Use variable.assign_mul if you want assignment to the variable value or 'x = x * y' if you want a new python Tensor object.
# Train on 10080 samples, validate on 2520 samples
# Epoch 1/10
# 10080/10080 [==============================] - 5645s 560ms/step - loss: 0.5027 - acc: 0.7484 - val_loss: 0.3977 - val_acc: 0.8187
#
# Epoch 00001: val_loss improved from inf to 0.39775, saving model to weights_densenet-169.hdf5
# Epoch 2/10
# 10080/10080 [==============================] - 5472s 543ms/step - loss: 0.3517 - acc: 0.8456 - val_loss: 0.3041 - val_acc: 0.8725
#
# Epoch 00002: val_loss improved from 0.39775 to 0.30411, saving model to weights_densenet-169.hdf5
# Epoch 3/10
# 10080/10080 [==============================] - 5458s 541ms/step - loss: 0.2924 - acc: 0.8772 - val_loss: 0.2556 - val_acc: 0.8969
#
# Epoch 00003: val_loss improved from 0.30411 to 0.25562, saving model to weights_densenet-169.hdf5
# Epoch 4/10
# 10080/10080 [==============================] - 5475s 543ms/step - loss: 0.2565 - acc: 0.8959 - val_loss: 0.2235 - val_acc: 0.9123
#
# Epoch 00004: val_loss improved from 0.25562 to 0.22353, saving model to weights_densenet-169.hdf5
# Epoch 5/10
# 10080/10080 [==============================] - 5457s 541ms/step - loss: 0.2302 - acc: 0.9089 - val_loss: 0.2022 - val_acc: 0.9214
#
# Epoch 00005: val_loss improved from 0.22353 to 0.20222, saving model to weights_densenet-169.hdf5
# Epoch 6/10
# 10080/10080 [==============================] - 5451s 541ms/step - loss: 0.2110 - acc: 0.9179 - val_loss: 0.1871 - val_acc: 0.9277
#
# Epoch 00006: val_loss improved from 0.20222 to 0.18709, saving model to weights_densenet-169.hdf5
# Epoch 7/10
# 10080/10080 [==============================] - 5450s 541ms/step - loss: 0.1918 - acc: 0.9270 - val_loss: 0.1747 - val_acc: 0.9328
#
# Epoch 00007: val_loss improved from 0.18709 to 0.17473, saving model to weights_densenet-169.hdf5
# Epoch 8/10
# 10080/10080 [==============================] - 5446s 540ms/step - loss: 0.1790 - acc: 0.9326 - val_loss: 0.1647 - val_acc: 0.9362
#
# Epoch 00008: val_loss improved from 0.17473 to 0.16473, saving model to weights_densenet-169.hdf5
# Epoch 9/10
# 10080/10080 [==============================] - 5445s 540ms/step - loss: 0.1663 - acc: 0.9382 - val_loss: 0.1572 - val_acc: 0.9393
#
# Epoch 00009: val_loss improved from 0.16473 to 0.15724, saving model to weights_densenet-169.hdf5
# Epoch 10/10
# 10080/10080 [==============================] - 5450s 541ms/step - loss: 0.1555 - acc: 0.9426 - val_loss: 0.1510 - val_acc: 0.9416
#
# Epoch 00010: val_loss improved from 0.15724 to 0.15099, saving model to weights_densenet-169.hdf5

# %% [markdown]
# # further training

# %%
early_stops = EarlyStopping(patience=3, monitor='val_acc')
checkpointer = ModelCheckpoint(filepath='weights_densenet-169_1.hdf5', verbose=1, save_best_only=True)
# Start Fine-tuning
model.load_weights('weights_densenet-169.hdf5')
model.fit(Xtrain, ytrain, 
          validation_data=(Xvalid, yvalid),
          batch_size=16,
          nb_epoch=15,
          shuffle=True,
          verbose=1,
          callbacks=[checkpointer])
# Out:
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:11: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   # This is added back by InteractiveShellApp.init_path()
# WARNING:tensorflow:Variable *= will be deprecated. Use variable.assign_mul if you want assignment to the variable value or 'x = x * y' if you want a new python Tensor object.
# Train on 10080 samples, validate on 2520 samples
# Epoch 1/15
# 10080/10080 [==============================] - 5826s 578ms/step - loss: 0.1440 - acc: 0.9487 - val_loss: 0.1453 - val_acc: 0.9438
#
# Epoch 00001: val_loss improved from inf to 0.14533, saving model to weights_densenet-169_1.hdf5
# Epoch 2/15
# 10080/10080 [==============================] - 5640s 560ms/step - loss: 0.1358 - acc: 0.9519 - val_loss: 0.1419 - val_acc: 0.9448
#
# Epoch 00002: val_loss improved from 0.14533 to 0.14188, saving model to weights_densenet-169_1.hdf5
# Epoch 3/15
# 10080/10080 [==============================] - 5508s 546ms/step - loss: 0.1259 - acc: 0.9566 - val_loss: 0.1370 - val_acc: 0.9469
#
# Epoch 00003: val_loss improved from 0.14188 to 0.13705, saving model to weights_densenet-169_1.hdf5
# Epoch 4/15
# 10080/10080 [==============================] - 5604s 556ms/step - loss: 0.1174 - acc: 0.9600 - val_loss: 0.1351 - val_acc: 0.9475
#
# Epoch 00004: val_loss improved from 0.13705 to 0.13514, saving model to weights_densenet-169_1.hdf5
# Epoch 5/15
# 10080/10080 [==============================] - 6414s 636ms/step - loss: 0.1104 - acc: 0.9632 - val_loss: 0.1310 - val_acc: 0.9490
#
# Epoch 00005: val_loss improved from 0.13514 to 0.13095, saving model to weights_densenet-169_1.hdf5
# Epoch 6/15
#    16/10080 [..............................] - ETA: 1:21:06 - loss: 0.1522 - acc: 0.9485
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-d4244930892b> in <module>()
#       9           shuffle=True,
#      10           verbose=1,
# ---> 11           callbacks=[checkpointer])
#
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# /home/chaikesh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
early_stops = EarlyStopping(patience=3, monitor='val_acc')
checkpointer = ModelCheckpoint(filepath='weights_densenet-169_2.hdf5', verbose=1, save_best_only=True)
# Start Fine-tuning
model.load_weights('weights_densenet-169_1.hdf5')
model.fit(Xtrain, ytrain, 
          validation_data=(Xvalid, yvalid),
          batch_size=16,
          nb_epoch=15,
          shuffle=True,
          verbose=1,
          callbacks=[checkpointer])

# %% [markdown]
# # prediction

# %%
model.load_weights('weights_densenet-169_1.hdf5')
pred_test = model.predict(X_test).round()
pred_test = pred_test.astype(np.int)

# %%
#submission
subm = pd.DataFrame()

subm['Image_name'] = test.Image_name

label_df = pd.DataFrame(data=pred_test, columns=label_cols)

subm = pd.concat([subm, label_df], axis=1)

subm.to_csv('submit_densenet_169_1.csv', index=False)
